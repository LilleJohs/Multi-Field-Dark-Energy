# %%
from stability_class import MultiFieldDarkEnergy
import numpy as np

params = {
    'V0': 2.19,
    'm': 400,
    'r0': 7*1e-4,
    'alpha': 2*1e-3,
    'x_p_init': 0.0,
    'x_t_init': 0.0,
    'y_1_init': 1e-5,
    'r_init_multiplier': 1, #r_i = x * r_0
    'p': 1.8,
    'potential': 'spinning',
    'metric': 'r_p'
}
c =MultiFieldDarkEnergy(params=params, N_min = 0, N_max = 10, gamma=1)
c.run_background_eq_of_motion()

H = c.get_H()
# Today is when H=H_0 (which is one in unites of H_0)
today_i = np.absolute(H-1).argmin()
size = today_i + 1
w = c.get_eq_of_state()[:size]
omega = c.get_omega_phi()[:size]
print(w[-1])
print(omega[-1])
print(min(c.get_de_sitter_bound()[:size]))

c.x_y_phase_plot()
c.plot_swampland_bound()
# Out:
# -0.9682765677507557
# 0.6907742375834871
# 0.6309240839943598
# c:\Users\johan\OneDrive\Dokumenter\Python\Multi-Field-Dark-Energy\stability_class.py:209: RuntimeWarning: invalid value encountered in true_divide
#   Omega_squared = 1/f*(dot_r * V_theta - f * dot_theta * V_r)**2 / (dot_r**2 + f * dot_theta**2)**2
# c:\Users\johan\OneDrive\Dokumenter\Python\Multi-Field-Dark-Energy\stability_class.py:351: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(N, 1/(1+4*omega**2/M_eff_squared), label='c_s^2')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11568/624903391.py in <module>
#      29
#      30 c.x_y_phase_plot()
# ---> 31 c.plot_swampland_bound()
#      32
#      33
#
# c:\Users\johan\OneDrive\Dokumenter\Python\Multi-Field-Dark-Energy\stability_class.py in plot_swampland_bound(self)
#     367         omega = x_p**2 + x_t**2 + y_1**2
#     368         plt.figure()
# --> 369         plt.plot(w, omega, label=r'$w, \Omega$')
#     370         plt.legend()
#     371         plt.show()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
#    2530 @_copy_docstring_and_deprecators(Figure.gca)
#    2531 def gca(**kwargs):
# -> 2532     return gcf().gca(**kwargs)
#    2533
#    2534
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\figure.py in gca(self, **kwargs)
#    1523                 "plt.subplot().")
#    1524         if self._axstack.empty():
# -> 1525             return self.add_subplot(1, 1, 1, **kwargs)
#    1526         else:
#    1527             return self._axstack()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#     782             projection_class, pkw = self._process_projection_requirements(
#     783                 *args, **kwargs)
# --> 784             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     785             key = (projection_class, pkw)
#     786         return self._add_axes_internal(ax, key)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     632
#     633         self._rasterization_zorder = None
# --> 634         self.cla()
#     635
#     636         # funcs used to format x and y - fall back on major formatters
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1243         self.containers = []
#    1244
# -> 1245         self.grid(False)  # Disable grid on init to use rcParameter
#    1246         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1247                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in grid(self, b, which, axis, **kwargs)
#    3062         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3063         if axis in ['x', 'both']:
# -> 3064             self.xaxis.grid(b, which=which, **kwargs)
#    3065         if axis in ['y', 'both']:
#    3066             self.yaxis.grid(b, which=which, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py in grid(self, b, which, **kwargs)
#    1431             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1432                                 if b is TOGGLE else b)
# -> 1433             self.set_tick_params(which='major', **gridkw)
#    1434         self.stale = True
#    1435
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py in set_tick_params(self, which, reset, **kw)
#     854             if which in ['major', 'both']:
#     855                 self._major_tick_kw.update(kwtrans)
# --> 856                 for tick in self.majorTicks:
#     857                     tick._apply_params(**kwtrans)
#     858             if which in ['minor', 'both']:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     605             if self._major:
#     606                 instance.majorTicks = []
# --> 607                 tick = instance._get_tick(major=True)
#     608                 instance.majorTicks.append(tick)
#     609                 return instance.majorTicks
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2057         else:
#    2058             tick_kw = self._minor_tick_kw
# -> 2059         return XTick(self.axes, 0, major=major, **tick_kw)
#    2060
#    2061     def set_label_position(self, position):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     418
#     419     def __init__(self, *args, **kwargs):
# --> 420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
#     422         self.tick1line.set(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     167             **grid_kw,
#     168         )
# --> 169         self.gridline.get_path()._interpolation_steps = \
#     170             GRIDLINE_INTERPOLATION_STEPS
#     171         self.label1 = mtext.Text(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     670             y = self._y
#     671
# --> 672         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     673         self._x, self._y = self._xy.T  # views
#     674
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\shape_base.py in column_stack(tup)
#     654             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655         arrays.append(arr)
# --> 656     return _nx.concatenate(arrays, 1)
#     657
#     658
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
